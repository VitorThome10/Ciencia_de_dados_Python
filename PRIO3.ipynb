# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorThome10/Ciencia_de_dados_Python/blob/main/PRIO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 

import yfinance as yf 

from datetime import datetime

# %%
acao = "PRIO3.SA"

dados = yf.download(tickers = acao)

dados
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-10-25  24.100000  24.400000  22.100800  23.340000  23.340000  25180000
# 2010-10-26  22.800200  23.400000  22.500000  22.500000  22.500000   7200000
# 2010-10-27  22.500000  23.200001  22.202400  22.700001  22.700001   3685000
# 2010-10-28  22.709999  22.709999  22.100000  22.500000  22.500000   2900000
# 2010-10-29  22.600000  22.900000  22.400000  22.740000  22.740000    825000
# ...               ...        ...        ...        ...        ...       ...
# 2023-03-31  32.419998  32.500000  31.160000  31.190001  31.190001  10983400
# 2023-04-03  32.599998  33.240002  32.150002  32.400002  32.400002  21657400
# 2023-04-04  34.299999  34.529999  32.860001  33.849998  33.849998  35100800
# 2023-04-05  33.500000  33.889999  32.470001  33.500000  33.500000  15729300
# ...

# %%
dados = yf.download(tickers=acao,start="2020-02-25", end =datetime.now())
dados
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-02-26   8.980000   9.048000   8.096000   8.180000   8.180000  20642000
# 2020-02-27   7.874000   8.492000   7.532000   7.960000   7.960000  27311500
# 2020-02-28   7.778000   7.932000   7.560000   7.880000   7.880000  25533000
# 2020-03-02   7.874000   8.588000   7.862000   8.460000   8.460000  16556500
# 2020-03-03   8.700000   8.996000   8.312000   8.356000   8.356000  22213000
# ...               ...        ...        ...        ...        ...       ...
# 2023-03-31  32.419998  32.500000  31.160000  31.190001  31.190001  10983400
# 2023-04-03  32.599998  33.240002  32.150002  32.400002  32.400002  21657400
# 2023-04-04  34.299999  34.529999  32.860001  33.849998  33.849998  35100800
# 2023-04-05  33.500000  33.889999  32.470001  33.500000  33.500000  15729300
# ...

# %%
dados = yf.download(tickers = acao, start= "2020-02-23",end= datetime.now())["Adj Close"]

dados

rentabilidade = dados[-1]/dados[0]-1

print("A rentabilidade de WEGE3 no periodo foi de ",rentabilidade)
# Out:
# [*********************100%***********************]  1 of 1 completed
# A rentabilidade de WEGE3 no periodo foi de  3.2836185340184247

# %%
import matplotlib.pyplot as plt



plt.plot(dados)
