# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorThome10/Ciencia_de_dados_Python/blob/main/Corr_Ibov_SP500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import yfinance as yf

# %%
# Correlação móvel entre o SP500 e o IBOV

acoes = ["^BVSP", "^GSPC"]

dados_indices = yf.download(acoes, "2000-01-01" ,  "2022-08-31")["Adj Close"]

retornos = dados_indices.pct_change().dropna()

corr_movel = retornos["^BVSP"].rolling(252).corr(retornos["^GSPC"]).dropna()

corr_movel.plot()
# Out:
# [*********************100%***********************]  2 of 2 completed
# <Axes: xlabel='Date'>
